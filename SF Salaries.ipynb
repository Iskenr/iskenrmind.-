# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Salaries.csv')

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
df['Status']
# Out:
# 0     NaN
# 83    NaN
# Name: Status, dtype: object

# %%
df1 = df[df['JobTitle'] == 'GEN']
df1
# Out:
#     Id    EmployeeName                                        JobTitle  \
# 0    1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 83  84  EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#       BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0   167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 83  230827.12         0.0        0.0      NaN  230827.12         230827.12
#
#     Year  Notes         Agency Status
# 0   2011    NaN  San Francisco    NaN
# 83  2011    NaN  San Francisco    NaN

# %%
df2 = df[df['EmployeeName'] == 'NATHANIEL FORD']
df2
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 83
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                2 non-null      int64
#  1   EmployeeName      2 non-null      object
#  2   JobTitle          2 non-null      object
#  3   BasePay           2 non-null      object
#  4   OvertimePay       2 non-null      object
#  5   OtherPay          2 non-null      object
#  6   Benefits          0 non-null      object
#  7   TotalPay          2 non-null      float64
#  8   TotalPayBenefits  2 non-null      float64
#  9   Year              2 non-null      int64
#  10  Notes             0 non-null      float64
#  11  Agency            2 non-null      object
#  12  Status            0 non-null      object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 332.0+ bytes

# %%
df['Status'] = df['Status'].replace(np.nan, 'Unknown', regex=True)
df.head()
# Out:
#     Id    EmployeeName                                        JobTitle  \
# 0    1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 83  84  EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#       BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0   167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 83  230827.12         0.0        0.0      NaN  230827.12         230827.12
#
#     Year  Notes         Agency   Status
# 0   2011    NaN  San Francisco  Unknown
# 83  2011    NaN  San Francisco  Unknown

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            2
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               2
# Agency              0
# Status              0
# dtype: int64

# %%
df['Benefits'] = df['Benefits'].fillna(0)
df.head()
# Out:
#     Id    EmployeeName                                        JobTitle  \
# 0    1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 83  84  EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#       BasePay OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0   167411.18         0.0  400184.25         0  567595.43         567595.43
# 83  230827.12         0.0        0.0         0  230827.12         230827.12
#
#     Year  Notes         Agency   Status
# 0   2011    NaN  San Francisco  Unknown
# 83  2011    NaN  San Francisco  Unknown

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
df['BasePay'] = df['BasePay'].fillna(0)
df['BasePay'] = df['BasePay'].astype(int)

# %%
df['BasePay'].mean()
# Out:
# np.float64(66053.34393961818)

# %%
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors='coerce')
df['OvertimePay'] = df['OvertimePay'].fillna(0)
df['OvertimePay'] = df['OvertimePay'].astype(int)
df['OvertimePay'].max()
# Out:
# 245131

# %%
df3 = df[df['EmployeeName'] == 'ALSON LEE']['TotalPayBenefits']
df3
# Out:
# 6    315981.05
# Name: TotalPayBenefits, dtype: float64

# %%
TotalPayBenefits = df.groupby('Year')['TotalPayBenefits'].sum()
TotalPayBenefits.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('TotalPayBenefits')
plt.title('TotalPayBenefits by Year')
plt.show()

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
top5_jobs = df.groupby('JobTitle')['TotalPay'].sum().nlargest(5)
top5_jobs
# Out:
# JobTitle
# Transit Operator    4.553076e+08
# Registered Nurse    4.322574e+08
# Firefighter         3.441351e+08
# Police Officer 3    3.266096e+08
# Deputy Sheriff      2.120763e+08
# Name: TotalPay, dtype: float64

# %%
plt.pie(top5_jobs, labels=top5_jobs.index, autopct='%1.1f%%')
plt.title('Top 5 Jobs')
plt.show()

# %%
df[df['Year'] == 2013]['JobTitle'].value_counts() == 1
# Out:
# JobTitle
# Transit Operator                False
# Special Nurse                   False
# Registered Nurse                False
# Public Svc Aide-Public Works    False
# Custodian                       False
#                                 ...
# IS Technician Assistant          True
# Chief, Fire Department           True
# Braillist                        True
# Victim & Witness Technician      True
# Senior Assessment Clerk          True
# Name: count, Length: 1051, dtype: bool

# %%
df[df['JobTitle'] == 'Chief']
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
def chief(string):
  if 'chief' in (string.lower()):
    return True
  else:
    return False

# %%
(df['JobTitle'].apply(lambda x: chief(x))).sum()
# Out:
# np.int64(627)

# %%
df['ntitles'] = df['JobTitle'].apply(len)

# %%
df[['ntitles', 'TotalPayBenefits']].corr ()
# Out:
#                    ntitles  TotalPayBenefits
# ntitles           1.000000         -0.036878
# TotalPayBenefits -0.036878          1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-90-621126171.py in <cell line: 0>()
# ----> 1 sns.heatmap(df.corr(), annot=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...
